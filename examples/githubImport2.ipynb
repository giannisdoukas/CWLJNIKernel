# %% [markdown]
# # Example on importing a workflow from github

# %%
% githubImport https://github.com/wilke/CWL-Quick-Start/blob/master/CWL/Workflows/pdf2wordcloud.cwl
# Out:
# tool 'pdftotext' registered
# tool 'wordcloud' registered
# tool 'pdf2wordcloud' registered

# %%
% view pdf2wordcloud
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.42.3 (20191010.1750)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="180pt" height="320pt"
#  viewBox="0.00 0.00 180.00 320.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 316)">
# <title>G</title>
# <polygon fill="#eeeeee" stroke="transparent" points="-4,4 -4,-316 176,-316 176,4 -4,4"/>
# <g id="clust1" class="cluster">
# <title>cluster_inputs</title>
# <polygon fill="#eeeeee" stroke="black" stroke-dasharray="5,2" points="16,-229 16,-304 156,-304 156,-229 16,-229"/>
# <text text-anchor="middle" x="100.92" y="-235.8" font-family="Times,serif" font-size="14.00">Workflow Inputs</text>
# </g>
# <g id="clust2" class="cluster">
# <title>cluster_outputs</title>
# ...

# %%
% execute pdf2wordcloud
pdf:
  class: File
  location: /Users/dks/Workspaces/CWLKernel/tests/input_data/text.pdf
# Out:
# Add data in memory
# {"words": {"location": "file:///private/tmp/CWLKERNEL_DATA/aa868e4e-43a7-470f-988a-48b50056cdb0/runtime_data/extracted.txt.png", "basename": "extracted.txt.png", "nameroot": "extracted.txt", "nameext": ".png", "class": "File", "checksum": "sha1$a07f14d5ce3e78fcead341fbb5f522d8a7384097", "size": 69187, "http://commonwl.org/cwltool#generation": 0, "_produced_by": "pdf2wordcloud", "id": "words", "result_counter": 0}}

# %%
% displayDataImage words
# Out:
# <image src="data:image/png; base64, ..." alt="/private/tmp/CWLKERNEL_DATA/aa868e4e-43a7-470f-988a-48b50056cdb0/results/c93f96bf-096b-4df3-843e-7aca96f6de24/extracted.txt.png">
