# %%
cwlVersion: v1.1
class: CommandLineTool
id: python
baseCommand: ["python"]

inputs:
  script:
    type: File
    inputBinding:
      position: 1
outputs:
  image:
    type: File
    outputBinding:
      glob: test.png
# Out:
# tool 'python' registered

# %%
% execute python
script:
    class: File
    location: /Users/dks/Workspaces/CWLKernel/tests/tools/visualize.py
# Out:
# Add data in memory
# {"image": {"location": "file:///private/tmp/CWLKERNEL_DATA/00ef6c78-567d-457a-a99d-18a697a2e4f8/runtime_data/test.png", "basename": "test.png", "nameroot": "test", "nameext": ".png", "class": "File", "checksum": "sha1$79632fdfb56adc9f09e1210a859c1e44e1ec7984", "size": 57087, "http://commonwl.org/cwltool#generation": 0, "id": "image"}}

# %%
% display_data_image image
# Out:
# <image src="data:image/png; base64, ..." alt="/private/tmp/CWLKERNEL_DATA/00ef6c78-567d-457a-a99d-18a697a2e4f8/results/e5bcc2ec-4414-4eec-b706-a67d473b03f2/test.png">
