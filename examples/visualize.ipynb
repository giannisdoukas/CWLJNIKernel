# %%
cwlVersion: v1.1
class: CommandLineTool
id: python
baseCommand: ["python"]

inputs:
  script:
    type: File
    inputBinding:
      position: 1
outputs:
  image:
    type: File
    outputBinding:
      glob: test.png
# Out:
# tool 'python' registered

# %%
% execute python
script:
    class: File
    location: /Users/dks/Workspaces/CWLKernel/tests/tools/visualize.py
# Out:
# Add data in memory
# {"image": {"location": "file:///private/tmp/CWLKERNEL_DATA/eb06cb3b-78bb-47cd-bb24-a019f80fd520/runtime_data/test.png", "basename": "test.png", "nameroot": "test", "nameext": ".png", "class": "File", "checksum": "sha1$43a78c983ce7b8d553939a25dc188e658f09ff6a", "size": 59825, "http://commonwl.org/cwltool#generation": 0, "id": "image", "result_counter": 0}}

# %%
% display_data_image image
# Out:
# <image src="data:image/png; base64, ..." alt="/private/tmp/CWLKERNEL_DATA/eb06cb3b-78bb-47cd-bb24-a019f80fd520/results/2c058294-2323-47a4-945a-aa526677f540/test.png">
