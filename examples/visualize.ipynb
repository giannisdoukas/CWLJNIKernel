# %%
cwlVersion: v1.1
class: CommandLineTool
id: python
baseCommand: ["python"]

inputs:
  script:
    type: File
    inputBinding:
      position: 1
outputs:
  image:
    type: File
    outputBinding:
      glob: test.png
# Out:
# tool 'python' registered

# %%
% execute python
script:
    class: File
    location: /Users/dks/Workspaces/CWLKernel/tests/tools/visualize.py
# Out:
# Add data in memory
# {"image": {"location": "file:///private/tmp/CWLKERNEL_DATA/0e4ccb6f-c03d-417a-8eac-53097aff1dde/runtime_data/test.png", "basename": "test.png", "nameroot": "test", "nameext": ".png", "class": "File", "checksum": "sha1$2ef56046c0d4cfa7c3b59adcb6101260e42ea227", "size": 60988, "http://commonwl.org/cwltool#generation": 0, "id": "image", "result_counter": 0}}

# %%
% displayDataImage image
# Out:
# <image src="data:image/png; base64, ..." alt="/private/tmp/CWLKERNEL_DATA/0e4ccb6f-c03d-417a-8eac-53097aff1dde/results/2427ba4f-f0e9-453d-8b40-8caa5f6369df/test.png">
